# %%
import pandas as pd
import numpy as np

# %%
#membuat dataframe dengan list
list1 = ['berenang','bersepeda','mendaki']
list2 = [50000,0,15000]

comp = list(zip(list1, list2)) #mengelompokkan list berdasarkan index

pd.DataFrame(comp, columns=['hobi','harga'])
# Out:
#         hobi  harga
# 0   berenang  50000
# 1  bersepeda      0
# 2    mendaki  15000

# %%
list2[1] = 1000 #bisa dimanipulasi

# %%
list2
# Out:
# [50000, 1000, 15000]

# %%
#membuat dataframe dengan tuple, perhatikan bedanya dengan list
tuple1 = ('Machine Learning',2)
tuple2 = ('Marketing',2)
tuple3 = ('Products',1)

pd.DataFrame([tuple1, tuple2, tuple3], columns=['pengalaman', 'lamanya'])
# Out:
#          pengalaman  lamanya
# 0  Machine Learning        2
# 1         Marketing        2
# 2          Products        1

# %%
tuple2[1]
# Out:
# 2

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
#numpy array
arr = np.array([[1,'Ari','2021-01-01'],[1,1,1],[2,'b','c']])

nump_arr = pd.DataFrame(arr, columns=['Joki','Nama','Tanggal'])
nump_arr
# Out:
#   Joki Nama     Tanggal
# 0    1  Ari  2021-01-01
# 1    1    1           1
# 2    2    b           c

# %%
arr
# Out:
# array([['1', 'Ari', '2021-01-01'],
#        ['1', 'mang', '1'],
#        ['2', 'b', 'c']], dtype='<U21')

# %%
nump_arr.info() #kalo numpy semua data type nya akan berupa object, perlu di convert dulu

# %%
nump_arr['Joki'] = nump_arr['Joki'].astype('int64')

# %%
arr[1,1] ='mang'
arr
# Out:
# array([['1', 'Ari', '2021-01-01'],
#        ['1', 'mang', '1'],
#        ['2', 'b', 'c']], dtype='<U21')

# %%
#pandas
series1 = pd.Series(['berenang','bersepeda','mendaki'])
series2 = pd.Series([50000,10000,15000])

pandas_pd = pd.DataFrame({'hobi':series1,'harga':series2})
pandas_pd
# Out:
#         hobi  harga
# 0   berenang  50000
# 1  bersepeda  10000
# 2    mendaki  15000

# %%
pandas_pd.info()

# %%
series1[2::-1]
# Out:
# 2      mendaki
# 1    bersepeda
# 0     berenang
# dtype: object

# %%
#array dan pandas hanya bisa menyimpan 1 tipe data
#tapi bisa untuk input macam - macam tipe data, nanti akan tersimpan sebagai object

# %%
#reading dataset
from google.colab import files

# %%
 files.upload()
# Out:
#      <input type="file" id="files-ecc5f9ce-df9e-48df-a1c1-34ba4450e30c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecc5f9ce-df9e-48df-a1c1-34ba4450e30c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-63b259460c61> in <module>()
# ----> 1 files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      66   local_filenames = dict()
#      67
# ---> 68   while result['action'] != 'complete':
#      69     result = _output.eval_js(
#      70         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
#
# ...

# %%
read_data = pd.read_csv('Book1.csv')
read_data.head()
# Out:
#    shopid  buyerid register_date country
# 0    2230     1024    12/10/2021      ID
# 1    2087     4678     9/19/2021      SZ
# 2    2830     2693      5/3/2019      SG
# 3    2812     3421    10/14/2020      MY
# 4    2532     3668     5/10/2020      MY

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
read.gdrive = pd.read_csv('link file di google drive')

# %%
list1 = ['462809','462643','466315','461735']
list2 = ['Male','Female','Female','Male']
list3 = ['No','Yes','Yes','Yes']
list4 = [22,38,67,67]
list5 = ['No','Yes','Yes','Yes']
list6 = ['Healthcare', 'Engineer','Engineer','Lawyer']
list7 = ['1.0',' ','1.0','0.0']
list8 = ['Low','Average','Low','High']
list9 = [4.0,3.0,1.0,2.0]
list10 = ['Cat_4','Cat_4','Cat_6','Cat_6']
list11 = ['D','A','B','B']

comp = list(zip(list1, list2, list3, list4, list5, list6, list7, list8, list9, list10, list11)) 

data_list = pd.DataFrame(comp, columns=['ID','Gender','Ever_Married','Age','Graduated','Profession','Work_Experience','Spending_Score','Family_Size',
                                   'Var_1','Segmentation'])
data_list
# Out:
#        ID  Gender Ever_Married  ...  Family_Size  Var_1 Segmentation
# 0  462809    Male           No  ...          4.0  Cat_4            D
# 1  462643  Female          Yes  ...          3.0  Cat_4            A
# 2  466315  Female          Yes  ...          1.0  Cat_6            B
# 3  461735    Male          Yes  ...          2.0  Cat_6            B
#
# [4 rows x 11 columns]

# %%
tuple1 = ('462809','Male','No',22,'No','Healthcare','1.0','Low',4.0,'Cat_4','D')
tuple2 = ('462643','Female','Yes',38,'Yes','Engineer',' ','Average',3.0,'Cat_4','A')
tuple3 = ('466315','Female','Yes',67,'Yes','Engineer','1.0','Low',1.0,'Cat_6','B')
tuple4 = ('461735','Male','Yes',67,'Yes','Lawyer','0.0','High',2.0,'Cat_6','B')

data_tuple = pd.DataFrame([tuple1, tuple2, tuple3, tuple4], columns=['ID','Gender','Ever_Married','Age','Graduated','Profession','Work_Experience',
                                                                     'Spending_Score','Family_Size','Var_1','Segmentation'])
data_tuple
# Out:
#        ID  Gender Ever_Married  ...  Family_Size  Var_1 Segmentation
# 0  462809    Male           No  ...          4.0  Cat_4            D
# 1  462643  Female          Yes  ...          3.0  Cat_4            A
# 2  466315  Female          Yes  ...          1.0  Cat_6            B
# 3  461735    Male          Yes  ...          2.0  Cat_6            B
#
# [4 rows x 11 columns]

# %%
arr = np.array([['462809','Male','No',22,'No','Healthcare','1.0','Low',4.0,'Cat_4','D'],
                ['462643','Female','Yes',38,'Yes','Engineer',' ','Average',3.0,'Cat_4','A'],
                 ['466315','Female','Yes',67,'Yes','Engineer','1.0','Low',1.0,'Cat_6','B'],
                ['461735','Male','Yes',67,'Yes','Lawyer','0.0','High',2.0,'Cat_6','B']])

data_arr = pd.DataFrame(arr, columns=['ID','Gender','Ever_Married','Age','Graduated','Profession','Work_Experience',
                                                                     'Spending_Score','Family_Size','Var_1','Segmentation'])
data_arr
# Out:
#        ID  Gender Ever_Married  ... Family_Size  Var_1 Segmentation
# 0  462809    Male           No  ...         4.0  Cat_4            D
# 1  462643  Female          Yes  ...         3.0  Cat_4            A
# 2  466315  Female          Yes  ...         1.0  Cat_6            B
# 3  461735    Male          Yes  ...         2.0  Cat_6            B
#
# [4 rows x 11 columns]

# %%
series1 = (['462809','462643','466315','461735'])
series2 = (['Male','Female','Female','Male'])
series3 = (['No','Yes','Yes','Yes'])
series4 = ([22,38,67,67])
series5 = (['No','Yes','Yes','Yes'])
series6 = (['Healthcare', 'Engineer','Engineer','Lawyer'])
series7 = (['1.0',' ','1.0','0.0'])
series8 = (['Low','Average','Low','High'])
series9 = ([4.0,3.0,1.0,2.0])
series10 = (['Cat_4','Cat_4','Cat_6','Cat_6'])
series11 = (['D','A','B','B'])

data_pandas = pd.DataFrame({'ID':series1,'Gender':series2,'Ever_Married':series3,'Age':series4,'Graduated':series5,'Profession':series6,
                          'Work_Experience':series7,'Spending_Score':series8,'Family_Size':series9,'Var_1':series10,'Segmentation':series11})
data_pandas
# Out:
#        ID  Gender Ever_Married  ...  Family_Size  Var_1 Segmentation
# 0  462809    Male           No  ...          4.0  Cat_4            D
# 1  462643  Female          Yes  ...          3.0  Cat_4            A
# 2  466315  Female          Yes  ...          1.0  Cat_6            B
# 3  461735    Male          Yes  ...          2.0  Cat_6            B
#
# [4 rows x 11 columns]
